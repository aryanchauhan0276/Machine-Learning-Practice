# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_iris

# %%
iris=load_iris()
df=pd.DataFrame(iris.data,iris.target,columns=['sepal length (cm)', 'sepal width (cm)','petal length (cm)', 'petal width (cm)'])

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 5.9 KB

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
Y=df[['petal width (cm)']]
X=df[['sepal length (cm)','sepal width (cm)','petal length (cm)']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
treemodel=DecisionTreeRegressor()

# %%
treemodel.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn import tree

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.3168768825301205, 0.9583333333333334, 'x[2] <= 2.45\nsquared_error = 0.546\nsamples = 105\nvalue = 1.239'),
#  Text(0.0963855421686747, 0.875, 'x[2] <= 1.55\nsquared_error = 0.012\nsamples = 31\nvalue = 0.248'),
#  Text(0.20663121234939757, 0.9166666666666667, 'True  '),
#  Text(0.03614457831325301, 0.7916666666666666, 'x[0] <= 4.35\nsquared_error = 0.004\nsamples = 23\nvalue = 0.217'),
#  Text(0.024096385542168676, 0.7083333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 0.1'),
#  Text(0.04819277108433735, 0.7083333333333334, 'x[1] <= 2.6\nsquared_error = 0.004\nsamples = 22\nvalue = 0.223'),
#  Text(0.03614457831325301, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 0.3'),
#  Text(0.060240963855421686, 0.625, 'x[0] <= 4.95\nsquared_error = 0.003\nsamples = 21\nvalue = 0.219'),
#  Text(0.03614457831325301, 0.5416666666666666, 'x[1] <= 3.5\nsquared_error = 0.002\nsamples = 9\nvalue = 0.2'),
#  Text(0.024096385542168676, 0.4583333333333333, 'x[1] <= 3.3\nsquared_error = 0.001\nsamples = 8\nvalue = 0.212'),
#  Text(0.012048192771084338, 0.375, 'squared_error = 0.0\nsamples = 7\nvalue = 0.2'),
#  Text(0.03614457831325301, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 0.3'),
#  Text(0.04819277108433735, 0.4583333333333333, 'squared_error = -0.0\nsamples = 1\nvalue = 0.1'),
#  Text(0.08433734939759036, 0.5416666666666666, 'x[1] <= 3.45\nsquared_error = 0.004\nsamples = 12\nvalue = 0.233'),
#  Text(0.07228915662650602, 0.4583333333333333, 'squared_error = 0.0\nsamples = 5\nvalue = 0.2'),
#  Text(0.0963855421686747, 0.4583333333333333, 'x[0] <= 5.2\nsquared_error = 0.005\nsamples = 7\nvalue = 0.257'),
#  Text(0.08433734939759036, 0.375, 'x[2] <= 1.45\nsquared_error = 0.005\nsamples = 4\nvalue = 0.3'),
#  Text(0.07228915662650602, 0.2916666666666667, 'x[0] <= 5.05\nsquared_error = 0.002\nsamples = 3\nvalue = 0.267'),
#  Text(0.060240963855421686, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 0.3'),
#  Text(0.08433734939759036, 0.20833333333333334, 'squared_error = 0.003\nsamples = 2\nvalue = 0.25'),
#  Text(0.0963855421686747, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 0.4'),
#  Text(0.10843373493975904, 0.375, 'squared_error = 0.0\nsamples = 3\nvalue = 0.2'),
#  Text(0.1566265060240964, 0.7916666666666666, 'x[1] <= 3.45\nsquared_error = 0.022\nsamples = 8\nvalue = 0.338'),
#  Text(0.13253012048192772, 0.7083333333333334, 'x[1] <= 3.35\nsquared_error = 0.017\nsamples = 4\nvalue = 0.275'),
#  Text(0.12048192771084337, 0.625, 'x[2] <= 1.65\nsquared_error = 0.023\nsamples = 2\nvalue = 0.35'),
#  Text(0.10843373493975904, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.2'),
#  Text(0.13253012048192772, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.5'),
#  Text(0.14457831325301204, 0.625, 'squared_error = 0.0\nsamples = 2\nvalue = 0.2'),
#  Text(0.18072289156626506, 0.7083333333333334, 'x[1] <= 3.65\nsquared_error = 0.02\nsamples = 4\nvalue = 0.4'),
#  Text(0.1686746987951807, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 0.6'),
#  Text(0.1927710843373494, 0.625, 'x[2] <= 1.65\nsquared_error = 0.009\nsamples = 3\nvalue = 0.333'),
#  Text(0.18072289156626506, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 0.2'),
#  Text(0.20481927710843373, 0.5416666666666666, 'squared_error = 0.0\nsamples = 2\nvalue = 0.4'),
#  Text(0.5373682228915663, 0.875, 'x[2] <= 4.75\nsquared_error = 0.187\nsamples = 74\nvalue = 1.654'),
#  Text(0.4271225527108434, 0.9166666666666667, '  False'),
#  Text(0.2921686746987952, 0.7916666666666666, 'x[2] <= 3.85\nsquared_error = 0.033\nsamples = 33\nvalue = 1.267'),
#  Text(0.2289156626506024, 0.7083333333333334, 'x[2] <= 3.15\nsquared_error = 0.002\nsamples = 7\nvalue = 1.029'),
#  Text(0.21686746987951808, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 1.1'),
#  Text(0.24096385542168675, 0.625, 'x[2] <= 3.75\nsquared_error = 0.001\nsamples = 6\nvalue = 1.017'),
#  Text(0.2289156626506024, 0.5416666666666666, 'squared_error = 0.0\nsamples = 5\nvalue = 1.0'),
#  Text(0.25301204819277107, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 1.1'),
#  Text(0.35542168674698793, 0.7083333333333334, 'x[2] <= 4.45\nsquared_error = 0.021\nsamples = 26\nvalue = 1.331'),
#  Text(0.2891566265060241, 0.625, 'x[1] <= 2.25\nsquared_error = 0.014\nsamples = 18\nvalue = 1.272'),
#  Text(0.27710843373493976, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.30120481927710846, 0.5416666666666666, 'x[0] <= 5.85\nsquared_error = 0.01\nsamples = 17\nvalue = 1.288'),
#  Text(0.25301204819277107, 0.4583333333333333, 'x[0] <= 5.75\nsquared_error = 0.01\nsamples = 11\nvalue = 1.255'),
#  Text(0.2289156626506024, 0.375, 'x[0] <= 5.35\nsquared_error = 0.003\nsamples = 9\nvalue = 1.289'),
#  Text(0.21686746987951808, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.4'),
#  Text(0.24096385542168675, 0.2916666666666667, 'x[2] <= 4.3\nsquared_error = 0.002\nsamples = 8\nvalue = 1.275'),
#  Text(0.2289156626506024, 0.20833333333333334, 'x[1] <= 2.95\nsquared_error = 0.001\nsamples = 7\nvalue = 1.286'),
#  Text(0.21686746987951808, 0.125, 'squared_error = 0.0\nsamples = 5\nvalue = 1.3'),
#  Text(0.24096385542168675, 0.125, 'x[2] <= 4.15\nsquared_error = 0.002\nsamples = 2\nvalue = 1.25'),
#  Text(0.2289156626506024, 0.041666666666666664, 'squared_error = 0.0\nsamples = 1\nvalue = 1.3'),
#  Text(0.25301204819277107, 0.041666666666666664, 'squared_error = -0.0\nsamples = 1\nvalue = 1.2'),
#  Text(0.25301204819277107, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.2'),
#  Text(0.27710843373493976, 0.375, 'x[1] <= 2.65\nsquared_error = 0.01\nsamples = 2\nvalue = 1.1'),
#  Text(0.26506024096385544, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.2'),
#  Text(0.2891566265060241, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.3493975903614458, 0.4583333333333333, 'x[1] <= 2.95\nsquared_error = 0.006\nsamples = 6\nvalue = 1.35'),
#  Text(0.3253012048192771, 0.375, 'x[1] <= 2.55\nsquared_error = 0.0\nsamples = 4\nvalue = 1.3'),
#  Text(0.3132530120481928, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.3'),
#  Text(0.3373493975903614, 0.2916666666666667, 'squared_error = 0.0\nsamples = 3\nvalue = 1.3'),
#  Text(0.37349397590361444, 0.375, 'x[0] <= 6.25\nsquared_error = 0.002\nsamples = 2\nvalue = 1.45'),
#  Text(0.3614457831325301, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.5'),
#  Text(0.3855421686746988, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.4'),
#  Text(0.42168674698795183, 0.625, 'x[0] <= 5.15\nsquared_error = 0.012\nsamples = 8\nvalue = 1.462'),
#  Text(0.40963855421686746, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 1.7'),
#  Text(0.43373493975903615, 0.5416666666666666, 'x[0] <= 6.55\nsquared_error = 0.005\nsamples = 7\nvalue = 1.429'),
#  Text(0.40963855421686746, 0.4583333333333333, 'x[0] <= 5.85\nsquared_error = 0.002\nsamples = 5\nvalue = 1.46'),
#  Text(0.39759036144578314, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 1.5'),
#  Text(0.42168674698795183, 0.375, 'x[1] <= 2.85\nsquared_error = 0.002\nsamples = 3\nvalue = 1.433'),
#  Text(0.40963855421686746, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.5'),
#  Text(0.43373493975903615, 0.2916666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 1.4'),
#  Text(0.4578313253012048, 0.4583333333333333, 'x[0] <= 6.8\nsquared_error = 0.002\nsamples = 2\nvalue = 1.35'),
#  Text(0.4457831325301205, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 1.3'),
#  Text(0.46987951807228917, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 1.4'),
#  Text(0.7825677710843374, 0.7916666666666666, 'x[1] <= 3.25\nsquared_error = 0.093\nsamples = 41\nvalue = 1.966'),
#  Text(0.5892319277108434, 0.7083333333333334, 'x[1] <= 2.65\nsquared_error = 0.07\nsamples = 34\nvalue = 1.885'),
#  Text(0.4819277108433735, 0.625, 'x[0] <= 5.85\nsquared_error = 0.055\nsamples = 4\nvalue = 1.6'),
#  Text(0.46987951807228917, 0.5416666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.4939759036144578, 0.5416666666666666, 'x[2] <= 5.3\nsquared_error = 0.002\nsamples = 3\nvalue = 1.467'),
#  Text(0.4819277108433735, 0.4583333333333333, 'squared_error = -0.0\nsamples = 2\nvalue = 1.5'),
#  Text(0.5060240963855421, 0.4583333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 1.4'),
#  Text(0.6965361445783133, 0.625, 'x[2] <= 5.15\nsquared_error = 0.06\nsamples = 30\nvalue = 1.923'),
#  Text(0.5662650602409639, 0.5416666666666666, 'x[0] <= 5.85\nsquared_error = 0.053\nsamples = 12\nvalue = 1.8'),
#  Text(0.5301204819277109, 0.4583333333333333, 'x[1] <= 2.75\nsquared_error = 0.047\nsamples = 3\nvalue = 2.1'),
#  Text(0.5180722891566265, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.5421686746987951, 0.375, 'x[0] <= 5.7\nsquared_error = 0.04\nsamples = 2\nvalue = 2.2'),
#  Text(0.5301204819277109, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.5542168674698795, 0.2916666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 2.4'),
#  Text(0.6024096385542169, 0.4583333333333333, 'x[0] <= 6.8\nsquared_error = 0.016\nsamples = 9\nvalue = 1.7'),
#  Text(0.5903614457831325, 0.375, 'x[2] <= 4.95\nsquared_error = 0.012\nsamples = 8\nvalue = 1.725'),
#  Text(0.5783132530120482, 0.2916666666666667, 'squared_error = 0.0\nsamples = 4\nvalue = 1.8'),
#  Text(0.6024096385542169, 0.2916666666666667, 'x[1] <= 2.9\nsquared_error = 0.013\nsamples = 4\nvalue = 1.65'),
#  Text(0.5783132530120482, 0.20833333333333334, 'x[1] <= 2.75\nsquared_error = 0.002\nsamples = 2\nvalue = 1.55'),
#  Text(0.5662650602409639, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 1.6'),
#  Text(0.5903614457831325, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 1.5'),
#  Text(0.6265060240963856, 0.20833333333333334, 'x[2] <= 5.05\nsquared_error = 0.003\nsamples = 2\nvalue = 1.75'),
#  Text(0.6144578313253012, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 1.7'),
#  Text(0.6385542168674698, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 1.8'),
#  Text(0.6144578313253012, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 1.5'),
#  Text(0.8268072289156626, 0.5416666666666666, 'x[1] <= 3.05\nsquared_error = 0.047\nsamples = 18\nvalue = 2.006'),
#  Text(0.7620481927710844, 0.4583333333333333, 'x[0] <= 7.5\nsquared_error = 0.033\nsamples = 12\nvalue = 1.95'),
#  Text(0.7289156626506024, 0.375, 'x[0] <= 7.15\nsquared_error = 0.023\nsamples = 9\nvalue = 1.889'),
#  Text(0.6987951807228916, 0.2916666666666667, 'x[0] <= 6.65\nsquared_error = 0.016\nsamples = 6\nvalue = 1.95'),
#  Text(0.6746987951807228, 0.20833333333333334, 'x[2] <= 5.4\nsquared_error = 0.007\nsamples = 4\nvalue = 1.875'),
#  Text(0.6626506024096386, 0.125, 'x[2] <= 5.25\nsquared_error = 0.002\nsamples = 2\nvalue = 1.95'),
#  Text(0.6506024096385542, 0.041666666666666664, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.6746987951807228, 0.041666666666666664, 'squared_error = -0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.6867469879518072, 0.125, 'squared_error = 0.0\nsamples = 2\nvalue = 1.8'),
#  Text(0.7228915662650602, 0.20833333333333334, 'x[0] <= 6.95\nsquared_error = 0.0\nsamples = 2\nvalue = 2.1'),
#  Text(0.7108433734939759, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 2.1'),
#  Text(0.7349397590361446, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 2.1'),
#  Text(0.7590361445783133, 0.2916666666666667, 'x[2] <= 5.95\nsquared_error = 0.016\nsamples = 3\nvalue = 1.767'),
#  Text(0.7469879518072289, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.6'),
#  Text(0.7710843373493976, 0.20833333333333334, 'x[2] <= 6.2\nsquared_error = 0.002\nsamples = 2\nvalue = 1.85'),
#  Text(0.7590361445783133, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.7831325301204819, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 1.8'),
#  Text(0.7951807228915663, 0.375, 'x[2] <= 6.35\nsquared_error = 0.016\nsamples = 3\nvalue = 2.133'),
#  Text(0.7831325301204819, 0.2916666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.8072289156626506, 0.2916666666666667, 'x[0] <= 7.65\nsquared_error = 0.002\nsamples = 2\nvalue = 2.05'),
#  Text(0.7951807228915663, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.1'),
#  Text(0.8192771084337349, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.891566265060241, 0.4583333333333333, 'x[0] <= 7.05\nsquared_error = 0.058\nsamples = 6\nvalue = 2.117'),
#  Text(0.8795180722891566, 0.375, 'x[2] <= 5.55\nsquared_error = 0.046\nsamples = 5\nvalue = 2.18'),
#  Text(0.8554216867469879, 0.2916666666666667, 'x[2] <= 5.45\nsquared_error = 0.042\nsamples = 3\nvalue = 2.067'),
#  Text(0.8433734939759037, 0.20833333333333334, 'x[0] <= 6.65\nsquared_error = 0.01\nsamples = 2\nvalue = 2.2'),
#  Text(0.8313253012048193, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.8554216867469879, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 2.1'),
#  Text(0.8674698795180723, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.8'),
#  Text(0.9036144578313253, 0.2916666666666667, 'x[2] <= 5.65\nsquared_error = 0.002\nsamples = 2\nvalue = 2.35'),
#  Text(0.891566265060241, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.4'),
#  Text(0.9156626506024096, 0.20833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.9036144578313253, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 1.8'),
#  Text(0.9759036144578314, 0.7083333333333334, 'x[1] <= 3.7\nsquared_error = 0.022\nsamples = 7\nvalue = 2.357'),
#  Text(0.963855421686747, 0.625, 'x[2] <= 5.85\nsquared_error = 0.021\nsamples = 6\nvalue = 2.383'),
#  Text(0.9518072289156626, 0.5416666666666666, 'x[2] <= 5.65\nsquared_error = 0.022\nsamples = 4\nvalue = 2.325'),
#  Text(0.9397590361445783, 0.4583333333333333, 'x[2] <= 5.5\nsquared_error = 0.003\nsamples = 2\nvalue = 2.35'),
#  Text(0.927710843373494, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.9518072289156626, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 2.4'),
#  Text(0.963855421686747, 0.4583333333333333, 'squared_error = 0.04\nsamples = 2\nvalue = 2.3'),
#  Text(0.9759036144578314, 0.5416666666666666, 'squared_error = -0.0\nsamples = 2\nvalue = 2.5'),
#  Text(0.9879518072289156, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 2.2')]
