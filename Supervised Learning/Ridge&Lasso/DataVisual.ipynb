# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("Algerian Fire Clean.csv")

# %%
df1.drop(df1[["day","month","year"]],axis=1,inplace=True)

# %%
df1
# Out:
#      Temperature    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0           29.0  57.0  18.0   0.0  65.7   7.6   7.6  1.3   3.4  0.5
# 1           29.0  61.0  13.0   1.3  64.4   7.6   7.6  1.0   3.9  0.4
# 2           26.0  82.0  22.0  13.1  47.1   7.1   7.1  0.3   2.7  0.1
# 3           25.0  89.0  13.0   2.5  28.6   6.9   6.9  0.0   1.7  0.0
# 4           27.0  77.0  16.0   0.0  64.8  14.2  14.2  1.2   3.9  0.5
# ..           ...   ...   ...   ...   ...   ...   ...  ...   ...  ...
# 238         30.0  65.0  14.0   0.0  85.4  44.5  44.5  4.5  16.9  6.5
# 239         28.0  87.0  15.0   4.4  41.1   8.0   8.0  0.1   6.2  0.0
# 240         27.0  87.0  29.0   0.5  45.9   7.9   7.9  0.4   3.4  0.2
# 241         24.0  54.0  18.0   0.1  79.7  15.2  15.2  1.7   5.1  0.7
# 242         24.0  64.0  15.0   0.2  67.3  16.5  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 0     not fire        0.0
# 1     not fire        0.0
# 2     not fire        0.0
# 3     not fire        0.0
# ...

# %%
sns.scatterplot(x="Temperature",y="Rain",data=df1)
# Out:
# <Axes: xlabel='Temperature', ylabel='Rain'>

# %%
df1["Classes"].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df1["Classes"]=np.where(df1["Classes"].str.contains("not fire"),0,1)

# %%
df1["Classes"].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df1
# Out:
#      Temperature    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0           29.0  57.0  18.0   0.0  65.7   7.6   7.6  1.3   3.4  0.5        0
# 1           29.0  61.0  13.0   1.3  64.4   7.6   7.6  1.0   3.9  0.4        0
# 2           26.0  82.0  22.0  13.1  47.1   7.1   7.1  0.3   2.7  0.1        0
# 3           25.0  89.0  13.0   2.5  28.6   6.9   6.9  0.0   1.7  0.0        0
# 4           27.0  77.0  16.0   0.0  64.8  14.2  14.2  1.2   3.9  0.5        0
# ..           ...   ...   ...   ...   ...   ...   ...  ...   ...  ...      ...
# 238         30.0  65.0  14.0   0.0  85.4  44.5  44.5  4.5  16.9  6.5        1
# 239         28.0  87.0  15.0   4.4  41.1   8.0   8.0  0.1   6.2  0.0        0
# 240         27.0  87.0  29.0   0.5  45.9   7.9   7.9  0.4   3.4  0.2        0
# 241         24.0  54.0  18.0   0.1  79.7  15.2  15.2  1.7   5.1  0.7        0
# 242         24.0  64.0  15.0   0.2  67.3  16.5  16.5  1.2   4.8  0.5        0
#
#      Region
# 0       0.0
# ...

# %%
plt.style.use('seaborn-v0_8')
df1.hist(bins=50,figsize=(20,15))
plt.show()

# %%
df1['Classes'].value_counts(normalize=True)
# Out:
# Classes
# 1    0.563786
# 0    0.436214
# Name: proportion, dtype: float64

# %%
plt.pie(df1['Classes'].value_counts(normalize=True),labels=['Fire','Not Fire'])

# %%
df1.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.376284
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.226941
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548  0.079135
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.298023
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.507397
# DMC             0.376284 -0.226941  0.079135 -0.298023  0.507397  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  1.000000
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.508643
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.941988
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.739521
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.511123
# ...

# %%
sns.boxplot(x=df1['FWI'])
# Out:
# <Axes: xlabel='FWI'>
