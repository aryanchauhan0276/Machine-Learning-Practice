# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv",header=1)
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
# dtypes: str(14)
# memory usage: 27.0 KB

# %%
df.columns = df.columns.str.strip()

# %%
df["day"]=pd.to_numeric(df["day"],errors="coerce")

# %%
df["month"]=pd.to_numeric(df["month"],errors="coerce")

# %%
df["year"]=pd.to_numeric(df["year"],errors="coerce")

# %%
df["Temperature"]=pd.to_numeric(df["Temperature"],errors="coerce")

# %%
df["RH"]=pd.to_numeric(df["RH"],errors="coerce")

# %%
df["Ws"]=pd.to_numeric(df["Ws"],errors="coerce")

# %%
df["Rain"]=pd.to_numeric(df["Rain"],errors="coerce")

# %%
df["FFMC"]=pd.to_numeric(df["FFMC"],errors="coerce")

# %%
df["DMC"]=pd.to_numeric(df["DC"],errors="coerce")

# %%
df["ISI"]=pd.to_numeric(df["ISI"],errors="coerce")

# %%
df["BUI"]=pd.to_numeric(df["BUI"],errors="coerce")

# %%
df["FWI"]=pd.to_numeric(df["FWI"],errors="coerce")

# %%
df["DC"]=pd.to_numeric(df["DC"],errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    float64
#  1   month        244 non-null    float64
#  2   year         244 non-null    float64
#  3   Temperature  244 non-null    float64
#  4   RH           244 non-null    float64
#  5   Ws           244 non-null    float64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      244 non-null    str
# dtypes: float64(13), str(1)
# memory usage: 27.0 KB

# %%
df[df.isnull().any(axis=1)]
# Out:
#       day  month    year  Temperature    RH    Ws  Rain  FFMC  DMC  DC   ISI  \
# 122   NaN    NaN     NaN          NaN   NaN   NaN   NaN   NaN  NaN NaN   NaN
# 123   NaN    NaN     NaN          NaN   NaN   NaN   NaN   NaN  NaN NaN   NaN
# 167  14.0    7.0  2012.0         37.0  37.0  18.0   0.2  88.9  NaN NaN  12.5
#
#       BUI  FWI    Classes
# 122   NaN  NaN        NaN
# 123   NaN  NaN  Classes
# 167  10.4  NaN        NaN

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1

# %%
df.isnull().sum()
# Out:
# day            2
# month          2
# year           2
# Temperature    2
# RH             2
# Ws             2
# Rain           2
# FFMC           2
# DMC            3
# DC             3
# ISI            2
# BUI            2
# FWI            3
# Classes        2
# Region         0
# dtype: int64

# %%
df=df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month    year  Temperature    RH    Ws  Rain  FFMC  DMC   DC  ISI  \
# 122  1.0    6.0  2012.0         32.0  71.0  12.0   0.7  57.1  8.2  8.2  0.6
#
#      BUI  FWI      Classes  Region
# 122  2.8  0.2  not fire        1.0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='str')

# %%
#df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']]=df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(int)

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   49.430864   49.430864    4.742387   16.690535
# ...

# %%
df.corr
# Out:
# <bound method DataFrame.corr of       day  month    year  Temperature    RH    Ws  Rain  FFMC   DMC    DC  \
# 0     1.0    6.0  2012.0         29.0  57.0  18.0   0.0  65.7   7.6   7.6
# 1     2.0    6.0  2012.0         29.0  61.0  13.0   1.3  64.4   7.6   7.6
# 2     3.0    6.0  2012.0         26.0  82.0  22.0  13.1  47.1   7.1   7.1
# 3     4.0    6.0  2012.0         25.0  89.0  13.0   2.5  28.6   6.9   6.9
# 4     5.0    6.0  2012.0         27.0  77.0  16.0   0.0  64.8  14.2  14.2
# ..    ...    ...     ...          ...   ...   ...   ...   ...   ...   ...
# 238  26.0    9.0  2012.0         30.0  65.0  14.0   0.0  85.4  44.5  44.5
# 239  27.0    9.0  2012.0         28.0  87.0  15.0   4.4  41.1   8.0   8.0
# 240  28.0    9.0  2012.0         27.0  87.0  29.0   0.5  45.9   7.9   7.9
# 241  29.0    9.0  2012.0         24.0  54.0  18.0   0.1  79.7  15.2  15.2
# 242  30.0    9.0  2012.0         24.0  64.0  15.0   0.2  67.3  16.5  16.5
#
#      ISI   BUI  FWI       Classes  Region
# ...

# %%
df.to_csv("Algerian Fire Clean.csv",index=False)
