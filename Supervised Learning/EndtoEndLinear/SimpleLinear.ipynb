# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("HW.csv")

# %%
df
# Out:
#     Weight  Height
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160
# 5       78     162
# 6       80     163
# 7       90     175
# 8       95     182
# 9       78     170
# 10      82     176
# 11      95     182
# 12     105     175
# 13     100     183
# 14      85     170
# 15      78     177
# 16      50     140
# 17      65     159
# 18      76     150
# 19      87     167
# 20      45     129
# 21      56     140
# 22      72     160

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  23 non-null     int64
#  1   Height  23 non-null     int64
# dtypes: int64(2)
# memory usage: 500.0 bytes

# %%
plt.plot(df["Height"],df["Weight"])

# %%
df.isnull().sum()
# Out:
# Weight    0
# Height    0
# dtype: int64

# %%
#df["Height"].value_counts()

# %%
#df["Weight"].value_counts()

# %%
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
df.describe()
# Out:
#            Weight      Height
# count   23.000000   23.000000
# mean    73.826087  158.391304
# std     17.872407   19.511626
# min     45.000000  120.000000
# 25%     59.000000  142.500000
# 50%     78.000000  162.000000
# 75%     86.000000  175.000000
# max    105.000000  183.000000

# %%
plt.plot(10,8)
sns.boxplot(y="Height",data=df)
# Out:
# <Axes: ylabel='Height'>

# %%
sns.lineplot(y="Height",x="Weight",data=df)
# Out:
# <Axes: xlabel='Weight', ylabel='Height'>

# %%
sns.scatterplot(y=df["Height"],x=df["Weight"])
# Out:
# <Axes: xlabel='Weight', ylabel='Height'>

# %%
Y=df[["Height"]]
X=df[["Weight"]]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
Scale=StandardScaler()
X_train=Scale.fit_transform(X_train)
X_test=Scale.transform(X_test)

# %%
Linear=LinearRegression()
Model=Linear.fit(X_train,Y_train)

# %%
Model.intercept_
# Out:
# array([157.8125])

# %%
Model.coef_
# Out:
# array([[17.03207732]])

# %%
plt.scatter(X_train,Y_train)
plt.plot(X_test,Model.predict(X_test),'r')

# %%
y_pred=Linear.predict(X_test)
y_pred
# Out:
# array([[162.55745791],
#        [162.55745791],
#        [128.70154204],
#        [179.99838426],
#        [149.22027893],
#        [190.25775271],
#        [142.03872102]])

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_test,Linear.predict(X_test))

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
MAE=mean_absolute_error(Y_test,y_pred)
MSE=mean_squared_error(Y_test,y_pred)
r2=r2_score(Y_test,y_pred)

# %%
print(MAE)
print(MSE)
print(r2)
# Out:
# 9.237776679921925
# 103.09818711844574
# 0.7828485570493535

# %%
#NewData
def final(new_weight):
    scaled=Scale.transform([[new_weight]])
    result=Linear.predict(scaled)
    print(result)

# %%
new_weight=int(input("Enter the value"))
final(new_weight)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 new_weight=int(input("Enter the value"))
#       2 final(new_weight)
#
# ValueError: invalid literal for int() with base 10: ''
