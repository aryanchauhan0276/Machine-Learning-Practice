# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs

# %%
X,Y=make_blobs(n_samples=1000,centers=3,n_features=2)

# %%
plt.scatter(X[:,0],X[:,1],c="k")

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scale=StandardScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=42)

# %%
X_train=Scale.fit_transform(X_train)
X_test=Scale.transform(X_test)

# %%
from sklearn.cluster import KMeans

# %%
#ElbowMethod
wcss=[]
for k in range(1,11):
    K=KMeans(n_clusters=k,init="k-means++")
    K.fit(X_train)
    wcss.append(K.inertia_)
print(wcss)
# Out:
# [1600.0, 498.08375393942674, 299.3100026580261, 232.17538776530466, 165.07419133433638, 118.25367339649249, 102.31124609936012, 86.02637376031683, 70.34149059329594, 63.39837564104981]
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
#plot
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel("No of cluster")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %%
k=KMeans(n_clusters=4,init="k-means++",random_state=42)

# %%
k.fit_predict(X_train)
# Out:
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# array([2, 2, 1, 3, 2, 0, 2, 2, 1, 1, 1, 1, 0, 1, 1, 1, 1, 0, 1, 2, 2, 1,
#        0, 0, 2, 3, 3, 1, 1, 2, 1, 3, 0, 3, 0, 2, 1, 2, 1, 2, 2, 2, 2, 1,
#        2, 2, 0, 1, 2, 0, 2, 2, 0, 1, 1, 3, 3, 0, 1, 2, 1, 2, 3, 2, 1, 2,
#        1, 2, 1, 1, 0, 2, 3, 0, 0, 1, 2, 1, 1, 3, 2, 2, 0, 2, 3, 3, 1, 2,
#        1, 1, 1, 1, 3, 3, 3, 2, 0, 1, 1, 2, 2, 1, 2, 2, 3, 1, 2, 1, 2, 2,
#        2, 1, 2, 2, 1, 3, 3, 2, 2, 2, 1, 1, 1, 1, 2, 1, 2, 2, 2, 0, 0, 2,
#        0, 2, 1, 2, 1, 0, 3, 1, 2, 1, 0, 1, 2, 1, 1, 2, 0, 1, 1, 1, 1, 1,
#        2, 2, 1, 3, 3, 2, 1, 1, 1, 2, 1, 1, 1, 1, 2, 1, 0, 1, 2, 0, 1, 2,
#        2, 1, 2, 2, 2, 2, 1, 2, 3, 1, 1, 2, 2, 1, 1, 1, 2, 1, 1, 0, 2, 3,
#        3, 2, 0, 2, 1, 0, 3, 3, 2, 0, 1, 1, 1, 2, 2, 3, 0, 3, 3, 2, 1, 1,
#        3, 2, 2, 2, 0, 3, 2, 3, 0, 2, 0, 0, 2, 2, 3, 2, 1, 3, 1, 0, 2, 2,
#        2, 0, 0, 1, 1, 3, 1, 2, 1, 1, 0, 2, 0, 2, 1, 2, 2, 1, 0, 2, 0, 2,
#        3, 2, 2, 3, 2, 2, 2, 2, 1, 3, 0, 2, 2, 0, 2, 3, 3, 1, 2, 2, 3, 1,
#        0, 3, 1, 0, 2, 2, 2, 3, 2, 3, 2, 1, 2, 0, 3, 2, 2, 1, 1, 3, 2, 3,
#        2, 3, 2, 1, 2, 1, 1, 0, 2, 2, 2, 2, 3, 1, 0, 2, 0, 3, 2, 2, 1, 2,
#        1, 3, 1, 3, 2, 1, 1, 1, 1, 1, 2, 1, 3, 0, 3, 1, 1, 0, 2, 1, 1, 2,
#        1, 0, 3, 3, 1, 2, 2, 2, 3, 1, 2, 2, 2, 0, 3, 1, 1, 0, 1, 1, 0, 0,
#        2, 3, 1, 0, 1, 1, 3, 2, 1, 0, 1, 3, 2, 1, 2, 0, 0, 2, 3, 1, 0, 3,
#        1, 1, 0, 3, 2, 3, 1, 2, 0, 2, 2, 3, 2, 0, 2, 0, 1, 0, 3, 2, 1, 1,
#        2, 1, 0, 3, 2, 1, 2, 2, 1, 2, 0, 2, 3, 2, 2, 0, 2, 3, 1, 0, 1, 2,
#        2, 0, 3, 2, 1, 1, 0, 1, 2, 1, 2, 2, 3, 3, 3, 1, 1, 1, 2, 0, 1, 3,
#        0, 2, 2, 1, 2, 1, 0, 1, 2, 1, 2, 3, 3, 2, 1, 2, 1, 2, 3, 1, 1, 1,
#        1, 1, 2, 1, 2, 3, 3, 3, 2, 2, 2, 2, 0, 3, 2, 1, 2, 0, 1, 0, 3, 1,
#        2, 3, 1, 0, 1, 1, 2, 1, 2, 2, 1, 2, 1, 2, 3, 3, 2, 1, 3, 1, 1, 2,
#        2, 0, 3, 3, 0, 2, 3, 3, 1, 3, 2, 1, 0, 1, 2, 3, 2, 1, 3, 2, 1, 3,
#        0, 1, 1, 2, 0, 3, 1, 3, 0, 2, 1, 2, 2, 1, 3, 0, 1, 2, 2, 3, 0, 0,
#        0, 2, 1, 1, 2, 3, 2, 1, 1, 2, 3, 0, 2, 1, 0, 3, 2, 2, 2, 0, 2, 2,
#        3, 2, 0, 0, 1, 1, 1, 2, 1, 3, 1, 2, 1, 3, 1, 2, 2, 3, 2, 1, 1, 2,
#        2, 2, 2, 1, 3, 1, 0, 0, 2, 1, 0, 1, 3, 3, 0, 0, 2, 2, 2, 2, 3, 0,
#        3, 2, 0, 2, 0, 1, 3, 2, 2, 3, 1, 1, 3, 1, 2, 0, 3, 1, 1, 2, 3, 3,
#        1, 3, 0, 2, 3, 2, 1, 3, 1, 1, 0, 3, 0, 0, 3, 1, 1, 1, 1, 1, 1, 3,
#        2, 1, 3, 3, 2, 0, 1, 1, 2, 1, 3, 0, 1, 3, 1, 1, 1, 3, 3, 0, 1, 1,
#        1, 2, 1, 2, 1, 2, 1, 0, 1, 2, 1, 2, 3, 0, 1, 1, 1, 2, 1, 1, 1, 3,
#        1, 1, 2, 2, 2, 3, 0, 1, 0, 2, 2, 1, 2, 2, 3, 3, 0, 0, 2, 2, 3, 1,
#        3, 0, 0, 0, 1, 2, 1, 2, 3, 2, 1, 1, 1, 2, 2, 3, 1, 1, 1, 1, 2, 2,
#        2, 2, 2, 0, 0, 3, 1, 0, 0, 3, 1, 2, 1, 1, 2, 1, 3, 0, 1, 1, 2, 1,
#        1, 0, 2, 2, 1, 0, 2, 0], dtype=int32)

# %%
pred=k.predict(X_test)

# %%
plt.scatter(X_test[:,0],X_test[:,1],c=pred)

# %%
#ValidateKvalue
#kneelocator&silhoutte scoring
# !pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.6-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\aryan chauhan\anaconda3\lib\site-packages (from kneed) (2.3.5)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\aryan chauhan\anaconda3\lib\site-packages (from kneed) (1.16.3)
# Downloading kneed-0.8.6-py3-none-any.whl (10 kB)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.6

# %%
from kneed import KneeLocator

# %%
KL=KneeLocator(range(1,11),wcss,curve="convex",direction="decreasing")

# %%
print(KL.elbow)
# Out:
# 3

# %%
#SIlhouteeScoring
from sklearn.metrics import silhouette_score

# %%
Sil=[]
for k in range(2,11):
    k1=k.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[149], line 3
#       1 Sil=[]
#       2 for k in range(2,11):
# ----> 3     k1=k.fit(X_train)
#
# AttributeError: 'int' object has no attribute 'fit'
