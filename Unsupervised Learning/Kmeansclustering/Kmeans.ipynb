# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs

# %%
X,Y=make_blobs(n_samples=1000,centers=3,n_features=2)

# %%
plt.scatter(X[:,0],X[:,1],c="k")

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scale=StandardScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=42)

# %%
X_train=Scale.fit_transform(X_train)
X_test=Scale.transform(X_test)

# %%
from sklearn.cluster import KMeans

# %%
#ElbowMethod
wcss=[]
for k in range(1,11):
    K=KMeans(n_clusters=k,init="k-means++")
    K.fit(X_train)
    wcss.append(K.inertia_)
print(wcss)
# Out:
# [1599.9999999999984, 348.6747065318415, 117.6420014839455, 95.32930328426575, 93.63343748507893, 56.3913455771109, 51.23473758589226, 45.81470511251089, 40.161931018409376, 37.753919778415245]
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
#plot
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel("No of cluster")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %%
k=KMeans(n_clusters=4,init="k-means++")

# %%
k.fit_predict(X_train)
# Out:
# c:\Users\Aryan Chauhan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# array([2, 0, 2, 2, 3, 0, 3, 0, 1, 2, 0, 0, 0, 1, 0, 2, 3, 2, 3, 1, 0, 1,
#        1, 2, 0, 1, 1, 1, 0, 2, 0, 0, 1, 2, 3, 0, 1, 2, 0, 1, 1, 0, 0, 1,
#        3, 2, 1, 0, 0, 0, 3, 0, 3, 2, 1, 0, 2, 1, 0, 2, 1, 3, 2, 1, 3, 3,
#        1, 3, 3, 0, 0, 0, 1, 2, 0, 1, 0, 0, 0, 0, 1, 1, 3, 0, 1, 2, 2, 2,
#        0, 3, 0, 2, 0, 0, 2, 1, 2, 0, 0, 3, 1, 2, 3, 0, 3, 1, 3, 3, 1, 1,
#        1, 1, 2, 2, 1, 0, 2, 2, 3, 1, 2, 0, 0, 1, 2, 0, 2, 0, 2, 2, 2, 2,
#        0, 2, 3, 0, 2, 3, 0, 2, 0, 0, 2, 3, 1, 1, 0, 1, 2, 0, 1, 2, 0, 3,
#        0, 3, 2, 2, 2, 2, 1, 3, 2, 2, 0, 2, 0, 2, 1, 2, 1, 1, 0, 2, 0, 0,
#        0, 0, 1, 2, 0, 2, 0, 0, 0, 3, 1, 2, 2, 2, 0, 0, 0, 3, 1, 2, 2, 2,
#        2, 2, 1, 2, 1, 3, 3, 2, 3, 1, 2, 0, 2, 3, 2, 2, 1, 2, 1, 2, 0, 0,
#        0, 0, 2, 2, 2, 0, 1, 2, 0, 2, 1, 1, 3, 0, 2, 2, 0, 0, 1, 3, 1, 0,
#        0, 2, 3, 2, 0, 0, 2, 2, 3, 2, 2, 1, 2, 2, 2, 3, 2, 0, 0, 2, 1, 2,
#        0, 0, 2, 0, 0, 3, 0, 1, 0, 0, 0, 0, 3, 0, 2, 1, 2, 0, 2, 2, 3, 2,
#        1, 1, 2, 3, 1, 0, 1, 0, 1, 2, 3, 0, 0, 0, 2, 0, 1, 3, 1, 1, 1, 2,
#        1, 2, 2, 0, 0, 0, 0, 2, 0, 0, 0, 0, 3, 2, 0, 2, 2, 3, 2, 2, 2, 0,
#        0, 3, 1, 2, 2, 3, 2, 1, 2, 2, 1, 1, 0, 1, 0, 2, 1, 0, 2, 1, 1, 1,
#        1, 3, 0, 3, 2, 1, 2, 2, 0, 2, 1, 0, 0, 1, 2, 3, 3, 2, 1, 2, 0, 0,
#        2, 3, 2, 0, 1, 1, 0, 0, 0, 0, 3, 3, 1, 2, 2, 0, 2, 3, 2, 3, 2, 3,
#        0, 1, 0, 2, 0, 1, 3, 2, 2, 0, 2, 2, 0, 2, 0, 2, 3, 0, 2, 2, 2, 2,
#        0, 2, 3, 3, 2, 0, 0, 1, 1, 3, 0, 0, 2, 0, 1, 0, 3, 2, 0, 0, 3, 3,
#        0, 2, 2, 2, 0, 0, 2, 2, 2, 2, 3, 2, 2, 1, 2, 0, 0, 0, 1, 2, 2, 3,
#        3, 0, 0, 3, 0, 1, 0, 1, 0, 2, 2, 1, 0, 2, 2, 2, 0, 3, 0, 2, 0, 3,
#        3, 0, 1, 2, 2, 1, 3, 0, 2, 3, 0, 1, 2, 0, 2, 2, 1, 2, 2, 0, 0, 1,
#        2, 3, 0, 2, 0, 0, 1, 0, 0, 0, 1, 0, 2, 0, 0, 0, 0, 2, 2, 2, 1, 2,
#        0, 1, 0, 2, 1, 1, 2, 0, 0, 2, 2, 0, 0, 0, 3, 0, 3, 0, 2, 1, 2, 3,
#        0, 2, 2, 2, 0, 2, 0, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 2, 2, 2, 0, 2,
#        1, 2, 2, 0, 1, 2, 2, 1, 2, 3, 0, 0, 0, 3, 3, 0, 0, 0, 0, 1, 2, 0,
#        0, 3, 0, 2, 2, 2, 2, 1, 0, 2, 0, 3, 2, 2, 2, 0, 2, 0, 0, 1, 0, 0,
#        2, 3, 2, 0, 0, 0, 3, 1, 1, 0, 1, 1, 0, 2, 3, 2, 1, 2, 3, 1, 0, 2,
#        2, 3, 0, 0, 3, 3, 0, 2, 2, 1, 3, 0, 0, 2, 0, 2, 0, 2, 3, 2, 0, 2,
#        3, 2, 1, 2, 3, 0, 2, 3, 0, 3, 0, 0, 1, 2, 0, 2, 2, 2, 0, 2, 2, 0,
#        2, 2, 2, 0, 2, 2, 3, 1, 2, 0, 1, 2, 1, 0, 2, 2, 1, 1, 0, 3, 3, 2,
#        2, 1, 3, 2, 3, 0, 1, 3, 1, 0, 2, 0, 1, 0, 1, 2, 2, 1, 0, 0, 0, 2,
#        2, 1, 0, 0, 0, 1, 3, 1, 1, 2, 2, 1, 2, 0, 0, 1, 2, 2, 2, 0, 1, 0,
#        2, 0, 0, 0, 1, 0, 2, 2, 3, 1, 2, 0, 3, 0, 0, 0, 0, 0, 2, 2, 0, 1,
#        0, 1, 0, 2, 0, 3, 1, 1, 3, 0, 3, 0, 0, 0, 0, 3, 3, 3, 3, 0, 2, 2,
#        0, 1, 2, 0, 3, 0, 0, 3], dtype=int32)

# %%
pred=k.predict(X_test)
