# %%
# %pip install NLTK
# %pip install spacy
# Out:
# Requirement already satisfied: NLTK in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (3.10.3)
# Requirement already satisfied: defusedxml in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from NLTK) (0.7.1)
# Requirement already satisfied: click in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from NLTK) (8.4.1)
# Requirement already satisfied: joblib in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from NLTK) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from NLTK) (2026.7.19)
# Requirement already satisfied: tqdm in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from NLTK) (4.70.0)
# Requirement already satisfied: colorama in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from click->NLTK) (0.4.6)
# Requirement already satisfied: spacy in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (3.8.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (0.27.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (4.70.0)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.5.0)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.5.20)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.1)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.14.2)
# Requirement already satisfied: httpcore==1.* in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Aryan Chauhan\anaconda3\envs\sklearn-env\Lib\site-packages (from jinja2->spacy) (3.0.3)

# %%
corpus=""" 
Hello Welcome, to Aryan Chauhan's Practice Session.
This is my sentence.
Please do look at the github repo!
"""

# %%
print(corpus)
# Out:
#
# Hello Welcome, to Aryan Chauhan's Practice Session.
# This is my sentence.
# Please do look at the github repo!

# %% [markdown]
# # Tokenization

# %%
from nltk.tokenize import sent_tokenize

# %%
docuements=sent_tokenize(corpus)

# %%
type(docuements)
print(docuements)
# Out:
# [" \nHello Welcome, to Aryan Chauhan's Practice Session.", 'This is my sentence.', 'Please do look at the github repo!']

# %%
# Word Tokeinzation
# Sentence->Words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Aryan',
#  'Chauhan',
#  "'s",
#  'Practice',
#  'Session',
#  '.',
#  'This',
#  'is',
#  'my',
#  'sentence',
#  '.',
#  'Please',
#  'do',
#  'look',
#  'at',
#  'the',
#  'github',
#  'repo',
#  '!']

# %%
for sentence in docuements:
    print(sentence)
# Out:
#
# Hello Welcome, to Aryan Chauhan's Practice Session.
# This is my sentence.
# Please do look at the github repo!

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Aryan',
#  'Chauhan',
#  "'",
#  's',
#  'Practice',
#  'Session',
#  '.',
#  'This',
#  'is',
#  'my',
#  'sentence',
#  '.',
#  'Please',
#  'do',
#  'look',
#  'at',
#  'the',
#  'github',
#  'repo',
#  '!']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Aryan',
#  'Chauhan',
#  "'s",
#  'Practice',
#  'Session.',
#  'This',
#  'is',
#  'my',
#  'sentence.',
#  'Please',
#  'do',
#  'look',
#  'at',
#  'the',
#  'github',
#  'repo',
#  '!']
