# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("business.csv")
df
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1      11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2      11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3      11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4      11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 93482  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
#
# ...

# %%
df.shape
# Out:
# (93487, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        93487 non-null  object
#  1   airline     93487 non-null  object
#  2   ch_code     93487 non-null  object
#  3   num_code    93487 non-null  int64
#  4   dep_time    93487 non-null  object
#  5   from        93487 non-null  object
#  6   time_taken  93487 non-null  object
#  7   stop        93487 non-null  object
#  8   arr_time    93487 non-null  object
#  9   to          93487 non-null  object
#  10  price       93487 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 7.8+ MB

# %%
df['date'].value_counts()
# Out:
# date
# 07-03-2022    2062
# 14-03-2022    2050
# 28-02-2022    2049
# 21-03-2022    2049
# 21-02-2022    2036
# 22-03-2022    2016
# 15-03-2022    2015
# 09-03-2022    2010
# 08-03-2022    2010
# 23-03-2022    2007
# 10-03-2022    2003
# 16-03-2022    1996
# 24-03-2022    1995
# 18-03-2022    1992
# 02-03-2022    1990
# 19-03-2022    1986
# 06-03-2022    1986
# 13-03-2022    1984
# 25-03-2022    1981
# 11-03-2022    1981
# 01-03-2022    1981
# 12-03-2022    1980
# 20-03-2022    1980
# 04-03-2022    1979
# 22-02-2022    1972
# 05-03-2022    1971
# 03-03-2022    1971
# 23-02-2022    1965
# 26-03-2022    1960
# 17-02-2022    1958
# 19-02-2022    1956
# 25-02-2022    1956
# 27-02-2022    1956
# 24-02-2022    1953
# 27-03-2022    1951
# 18-02-2022    1945
# 20-02-2022    1945
# 26-02-2022    1943
# 28-03-2022    1934
# 16-02-2022    1926
# 17-03-2022    1910
# 15-02-2022    1903
# 31-03-2022    1890
# 30-03-2022    1853
# 29-03-2022    1790
# 14-02-2022    1665
# 13-02-2022    1424
# ...

# %%
df['time_taken'].unique()
# Out:
# array(['02h 00m', '02h 15m', '24h 45m', '26h 30m', '06h 40m', '02h 10m',
#        '17h 45m', '22h 45m', '17h 55m', '11h 00m', '15h 15m', '11h 25m',
#        '15h 50m', '21h 35m', '26h 00m', '05h 45m', '16h 10m', '28h 10m',
#        '19h 20m', '23h 50m', '27h 10m', '06h 00m', '19h 30m', '26h 50m',
#        '12h 25m', '14h 40m', '24h 25m', '26h 40m', '28h 15m', '15h 35m',
#        '17h 50m', '18h 15m', '02h 05m', '03h 30m', '03h 45m', '17h 30m',
#        '25h 35m', '06h 20m', '02h 20m', '08h 00m', '20h 35m', '10h 05m',
#        '04h 25m', '23h 55m', '14h 10m', '15h 45m', '04h 50m', '07h 00m',
#        '20h 50m', '23h 45m', '26h 25m', '13h 15m', '21h 25m', '06h 25m',
#        '05h 00m', '30h 05m', '05h 20m', '08h 15m', '12h 35m', '15h 30m',
#        '23h 30m', '27h 45m', '08h 25m', '12h 10m', '20h 25m', '24h 50m',
#        '09h 05m', '15h 25m', '07h 35m', '11h 10m', '12h 45m', '13h 45m',
#        '18h 00m', '07h 55m', '06h 15m', '08h 55m', '24h 55m', '29h 40m',
# ...

# %%
df['price']=df['price'].str.replace(",","").astype(float)

# %%
df['price'].isnull().unique()
# Out:
# array([False])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        93487 non-null  object
#  1   airline     93487 non-null  object
#  2   ch_code     93487 non-null  object
#  3   num_code    93487 non-null  int64
#  4   dep_time    93487 non-null  object
#  5   from        93487 non-null  object
#  6   time_taken  93487 non-null  object
#  7   stop        93487 non-null  object
#  8   arr_time    93487 non-null  object
#  9   to          93487 non-null  object
#  10  price       93487 non-null  float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 7.8+ MB

# %%
plt.plot(20,20)
sns.barplot(y="price",x="airline",data=df,hue="to")
plt.xlabel("Airline")
plt.ylabel("Price")
plt.show()

# %%
sns.boxplot(x='airline',y='price',data=df)
# Out:
# <Axes: xlabel='airline', ylabel='price'>

# %%
df[df['from'].isnull()].value_counts
# Out:
# <bound method DataFrame.value_counts of Empty DataFrame
# Columns: [date, airline, ch_code, num_code, dep_time, from, time_taken, stop, arr_time, to, price]
# Index: []>

# %%
df['from'].unique()
# Out:
# array(['Delhi', 'Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai'],
#       dtype=object)

# %%
plt.plot()
sns.boxplot(x="from",y="to",data=df)
plt.ylabel("TO")
plt.xlabel("From")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        93487 non-null  object
#  1   airline     93487 non-null  object
#  2   ch_code     93487 non-null  object
#  3   num_code    93487 non-null  int64
#  4   dep_time    93487 non-null  object
#  5   from        93487 non-null  object
#  6   time_taken  93487 non-null  object
#  7   stop        93487 non-null  object
#  8   arr_time    93487 non-null  object
#  9   to          93487 non-null  object
#  10  price       93487 non-null  float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 7.8+ MB

# %%
plt.plot()
sns.boxplot(x="airline",y="from",data=df)
plt.show()

# %%
plt.plot()
sns.countplot(x="from",data=df)
plt.show()

# %%
plt.plot()
sns.barplot(x="from",y="to",data=df,hue="airline")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        93487 non-null  object
#  1   airline     93487 non-null  object
#  2   ch_code     93487 non-null  object
#  3   num_code    93487 non-null  int64
#  4   dep_time    93487 non-null  object
#  5   from        93487 non-null  object
#  6   time_taken  93487 non-null  object
#  7   stop        93487 non-null  object
#  8   arr_time    93487 non-null  object
#  9   to          93487 non-null  object
#  10  price       93487 non-null  float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 7.8+ MB

# %%
plt.plot(10,10)
sns.countplot(x="date",data=df,hue="airline")
# Out:
# <Axes: xlabel='date', ylabel='count'>

# %%
df['arr_time'].unique()
# Out:
# array(['20:00', '21:15', '20:45', '23:55', '22:00', '15:00', '17:25',
#        '14:30', '08:35', '08:05', '18:15', '21:50', '08:15', '20:15',
#        '11:25', '20:05', '23:30', '13:00', '20:20', '11:40', '22:50',
#        '09:05', '10:10', '22:10', '11:15', '18:00', '21:35', '23:25',
#        '15:15', '19:15', '11:10', '15:05', '11:35', '16:25', '23:00',
#        '16:00', '14:00', '00:10', '08:20', '12:35', '18:20', '15:55',
#        '21:05', '17:05', '22:35', '23:05', '17:50', '14:45', '16:30',
#        '13:35', '13:45', '17:40', '15:50', '11:30', '10:00', '09:00',
#        '10:15', '23:50', '07:55', '09:45', '19:05', '12:50', '11:00',
#        '13:25', '09:40', '12:15', '15:40', '23:40', '17:10', '17:15',
#        '07:10', '09:55', '08:10', '20:30', '09:20', '23:20', '22:25',
#        '10:35', '08:00', '22:15', '00:30', '14:20', '20:25', '20:50',
#        '22:40', '08:50', '10:45', '20:55', '17:45', '10:50', '11:50',
# ...

# %%
plt.plot()
sns.barplot(x="arr_time",data=df)
# Out:
# <Axes: xlabel='arr_time'>

# %%
sns.countplot(x="time_taken",data=df)
# Out:
# <Axes: xlabel='time_taken', ylabel='count'>
